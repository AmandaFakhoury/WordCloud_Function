# %%
from wordcloud_DataFunction import *

# %%
df = pd.read_csv("cleaned_reviews.csv")
df.head()
# Out:
#    book_id  profile_id                                               text  \
# 0    94589      194643  writer want writer know writer this vital talk...
# 1    94589      221889  interesting essays relative many people length...
# 2    94589       88586  enjoyed this nonfiction collection essays abou...
# 3    94589      144982  should absolutely required students well those...
# 4    94589      180690  always pick these about writing even though wr...
#
#      Title           isbn      company_name billing_group_id  \
# 0  Scratch  9781501134579  Simon & Schuster              S&S
# 1  Scratch  9781501134579  Simon & Schuster              S&S
# 2  Scratch  9781501134579  Simon & Schuster              S&S
# 3  Scratch  9781501134579  Simon & Schuster              S&S
# 4  Scratch  9781501134579  Simon & Schuster              S&S
#
#    reviews_submitted                                         Clean_Text
# 0                 24    writer want writer writer vital talk money time
# ...

# %%
title = 'Scratch'
minfreq = 3
maxwords = 200

# %%
wordcloud_data(df , title , minfreq , maxwords)
# Out:
# Data or wordcloud or both? wordcloud

# %%
wordcloud_data(df , title , minfreq , maxwords)
# Out:
# Data or wordcloud or both? data
#     Words  Frequency
# 0  writer         49
# 2  writer         49
# 3  writer         49
# 6   money         25
# 7    time          7

# %%
wordcloud_data(df , title , minfreq , maxwords)
# Out:
# Data or wordcloud or both? Data
#     Words  Frequency
# 0  writer         49
# 2  writer         49
# 3  writer         49
# 6   money         25
# 7    time          7
